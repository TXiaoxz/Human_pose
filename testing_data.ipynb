# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
df = pd.read_csv('mpii_dataset.csv')
df.head(10)
# Out:
#    Unnamed: 0           NAME  r ankle_X  r ankle_Y  r knee_X  r knee_Y  \
# 0           0  015601864.jpg        620        394       616       269
# 1           0  015599452.jpg         -1         -1        -1        -1
# 2           0  005808361.jpg        804        711       816       510
# 3           0  086617615.jpg        301        461       305       375
# 4           0  060111501.jpg        980        322       896       318
# 5           0  070807258.jpg        461        398       509       335
# 6           0  002058449.jpg        918        456       659       518
# 7           0  021233911.jpg         -1         -1       355       408
# 8           0  018182497.jpg        325        349       341       327
# 9           0  018340451.jpg        392        390       388       300
#
#    r hip_X  r hip_Y  l hip_X  l hip_Y  ...  r shoulder_Y  l shoulder_X  \
# 0      573      185      647      188  ...           167           692
# 1      806      543      720      593  ...           281           719
# 2      908      438     1040      454  ...           253          1067
# 3      201      340      294      342  ...           261           314
# 4      865      248      943      226  ...           147           923
# 5      517      218      570      203  ...           280           652
# 6      713      413      979      288  ...           270           877
# 7      269      354      432      333  ...           168           389
# 8      326      302      385      277  ...           231           360
# 9      289      296      302      283  ...           194           292
#
#    l shoulder_Y  l elbow_X  l elbow_Y  l wrist_X  l wrist_Y     Scale  \
# 0           185        693        240        688        313  3.021046
# 1           299        711        516        545        466  5.641276
# 2           253       1167        353       1142        478  4.718488
# 3           264        327        320        362        346  2.681349
# 4           123        995        163        961        223  3.806403
# 5           265        636        356        621        417  2.400120
# 6           247       1112        384       1012        489  8.280870
# 7           147        492        259        413        321  3.781047
# 8           187        406        218        374        258  3.523671
# 9           187        320        262        362        276  1.949178
#
#                                             Activity                Category
# 0                                            curling                  sports
# 1                                            curling                  sports
# 2                                            curling                  sports
# 3                                            curling                  sports
# 4                                            curling                  sports
# 5                                            curling                  sports
# 6                                            curling                  sports
# 7                                    sitting quietly  inactivity quiet/light
# 8                                    sitting quietly  inactivity quiet/light
# 9  sitting, talking in person, on the phone, comp...           miscellaneous
#
# [10 rows x 37 columns]

# %%
def imag(ix):
    img = df['NAME'][ix]
    print(img)
    
    im = Image.open('MPII/images/' + img )
    print(im.size)
    implot = plt.imshow(im)
    
    px=2
    
    while px <34:
        col = df.columns[px]
        x = df[col][ix]
        col = df.columns[px+1]
        y = df[col][ix]
        print(col,x,y)
        plt.scatter([[x]],[[y]])
        px=px+2
imag(182)
# Out:
# 016949275.jpg
# (1280, 720)
# r ankle_Y -1 -1
# r knee_Y 1264 163
# r hip_Y 935 429
# l hip_Y 912 355
# l knee_Y 1249 137
# l ankle_Y -1 -1
# pelvis_Y 924 392
# thorax_Y 524 462
# upper neck_Y 450.4581 462.2125
# head top_Y 251.5419 462.7875
# r wrist_Y 1051 579
# r elbow_Y 809 576
# r shoulder_Y 510 510
# l shoulder_Y 538 414
# l elbow_Y 794 444
# l wrist_Y 1005 462

# %%
df[:]
# Out:
#        Unnamed: 0           NAME  r ankle_X  r ankle_Y  r knee_X  r knee_Y  \
# 0               0  015601864.jpg        620        394       616       269
# 1               0  015599452.jpg         -1         -1        -1        -1
# 2               0  005808361.jpg        804        711       816       510
# 3               0  086617615.jpg        301        461       305       375
# 4               0  060111501.jpg        980        322       896       318
# ...           ...            ...        ...        ...       ...       ...
# 17367           0  033474347.jpg        876        461       815       380
# 17368           0  082650067.jpg       1038        656       950       504
# 17369           0  072772110.jpg        562        617       558       539
# 17370           0  039361034.jpg        496        377       466       322
# 17371           0  084761779.jpg        362        350       347       297
#
#        r hip_X  r hip_Y  l hip_X  l hip_Y  ...  r shoulder_Y  l shoulder_X  \
# 0          573      185      647      188  ...           167           692
# 1          806      543      720      593  ...           281           719
# 2          908      438     1040      454  ...           253          1067
# 3          201      340      294      342  ...           261           314
# 4          865      248      943      226  ...           147           923
# ...        ...      ...      ...      ...  ...           ...           ...
# 17367      779      296      742      303  ...           214           663
# 17368      903      328      831      337  ...           204           729
# 17369      553      452      511      458  ...           377           490
# 17370      510      278      540      280  ...           253           466
# 17371      350      224      317      226  ...           168           288
#
#        l shoulder_Y  l elbow_X  l elbow_Y  l wrist_X  l wrist_Y     Scale  \
# 0               185        693        240        688        313  3.021046
# 1               299        711        516        545        466  5.641276
# 2               253       1167        353       1142        478  4.718488
# 3               264        327        320        362        346  2.681349
# 4               123        995        163        961        223  3.806403
# ...             ...        ...        ...        ...        ...       ...
# 17367           223        674        286        631        260  2.003677
# 17368           220        704        332        675        269  3.235820
# 17369           378        470        411        461        414  1.494952
# 17370           251        436        293        410        325  1.459468
# 17371           177        279        199        268        194  1.189877
#
#           Activity        Category
# 0          curling          sports
# 1          curling          sports
# 2          curling          sports
# 3          curling          sports
# 4          curling          sports
# ...            ...             ...
# 17367  pushing car  transportation
# 17368  pushing car  transportation
# 17369  pushing car  transportation
# 17370  pushing car  transportation
# 17371  pushing car  transportation
#
# [17372 rows x 37 columns]
